# %%
import nltk
print(nltk.__file__)
# Out:
# c:\users\me\appdata\local\programs\python\python37\lib\site-packages\nltk\__init__.py

# %%
 nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
from nltk.corpus import gutenberg

# %% [markdown]
# # still haver to figure out. directtly open using sentdex

# %%
with open('Gutenberg_austen-emma.txt', 'r') as myfile:
    data=myfile.read().replace('\n', '')

# %% [markdown]
# # pre process

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import string
import re
punct = set(string.punctuation)
stopWords = set(stopwords.words('english'))

#later can use punkt or other tokenizer
#also didn't perform spelling correction textblob
def preProcess(review):
    token = word_tokenize(review) 
    tokens = [t.lower() for t in token]
    filterd_words = [word for word in tokens if word not in stopWords]
    return ' '.join(filterd_words)
#' '.join(text for text in filterd_words if text not in punct)
print(sent_tokenize(preProcess(data)))
# Out:
# ["[ emma jane austen 1816 ] volume ichapter iemma woodhouse , handsome , clever , rich , comfortable homeand happy disposition , seemed unite best blessingsof existence ; lived nearly twenty-one years worldwith little distress vex her.she youngest two daughters affectionate , indulgent father ; , consequence sister 's marriage , mistress house early period .", "motherhad died long ago indistinctremembrance caresses ; place suppliedby excellent woman governess , fallen little shortof mother affection.sixteen years miss taylor mr. woodhouse 's family , less governess friend , fond daughters , particularly emma .", '_them_ intimacyof sisters .', "even miss taylor ceased hold nominaloffice governess , mildness temper hardly allowedher impose restraint ; shadow authority beingnow long passed away , living together friend andfriend mutually attached , emma liked ; highly esteeming miss taylor 's judgment , directed chiefly byher own.the real evils , indeed , emma 's situation power havingrather much way , disposition think littletoo well ; disadvantages threatenedalloy many enjoyments .", 'danger , however , presentso unperceived , means rank misfortuneswith her.sorrow came -- gentle sorrow -- shape anydisagreeable consciousness.', '-- miss taylor married .', "misstaylor 's loss first brought grief .", 'wedding-dayof beloved friend emma first sat mournful thoughtof continuance .', 'wedding , bride-people gone , father left dine together , prospectof third cheer long evening .', 'father composed himselfto sleep dinner , usual , sitand think lost.the event every promise happiness friend .', "mr. westonwas man unexceptionable character , easy fortune , suitable age , pleasant manners ; satisfaction consideringwith self-denying , generous friendship always wishedand promoted match ; black morning 's work her.the want miss taylor would felt every hour every day.she recalled past kindness -- kindness , affection sixteenyears -- taught played fiveyears old -- devoted powers attach amuseher health -- nursed various illnessesof childhood .", "large debt gratitude owing ; theintercourse last seven years , equal footing perfectunreserve soon followed isabella 's marriage , theirbeing left , yet dearer , tenderer recollection.she friend companion possessed : intelligent , well-informed , useful , gentle , knowing ways family , interested concerns , peculiarly interested , every pleasure , every scheme -- one could speakevery thought arose , affection heras could never find fault.how bear change ?", '-- true friend wasgoing half mile ; emma aware great mustbe difference mrs. weston , half mile , miss taylor house ; advantages , natural domestic , great danger sufferingfrom intellectual solitude .', 'dearly loved father , hewas companion .', 'could meet conversation , rational playful.the evil actual disparity ages ( mr. woodhouse hadnot married early ) much increased constitution habits ; valetudinarian life , without activityof mind body , much older man ways years ; though everywhere beloved friendliness heartand amiable temper , talents could recommended himat time.her sister , though comparatively little removed matrimony , settled london , sixteen miles , much beyondher daily reach ; many long october november evening mustbe struggled hartfield , christmas brought nextvisit isabella husband , little children , fill house , give pleasant society again.highbury , large populous village , almost amounting town , hartfield , spite separate lawn , shrubberies , name , really belong , afforded equals .', 'woodhouseswere first consequence .', 'looked .', 'hadmany acquaintance place , father universally civil , one among could accepted lieu misstaylor even half day .', 'melancholy change ; emmacould sigh , wish impossible things , till father awoke , made necessary cheerful.his spirits required support .', 'nervous man , easily depressed ; fond every body used , hating part ; hating change every kind .', "matrimony , origin change , always disagree ...

# %% [markdown]
# # Formatting to feed it to word2vec

# %%
print(punct)
# Out:
# {'=', ']', '&', '~', '[', '%', '_', '*', '<', ';', '|', '@', "'", '^', '(', ',', ':', '?', '+', '`', '"', '!', '-', '/', '>', ')', '{', '.', '#', '$', '}', '\\'}
